# %% [markdown]
# # ▒ 연관규칙분석(Association Rule) ▒

# %% [markdown]
# ## 0. 환경설정

# %%
import pandas as pd
import os
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ## 1. 데이터 준비

# %% [markdown]
# ### 데이터 설명
# #### 미국 Census Bureau의 Census Income데이터 베이스에 추출한 설문조사 자료
# - 관측치의 개수 : 48842개
# - 나이, 직업군, 교육정도 등의 주로 범주형인 15개의 변수 포함

# %%
Adult_file = os.getcwd()+'/data/Adult.csv'
Adult_df = pd.read_csv(Adult_file).transpose()

# %% [markdown]
# ### 데이터 변환

# %%
Adult_list = []
for i in range(0,len(Adult_df.columns)):
    Adult_list.append(Adult_df[i].to_string().split(","))

# %%
oht = TransactionEncoder()
oht_ary = oht.fit(Adult_list).transform(Adult_list)
df = pd.DataFrame(oht_ary, columns=oht.columns_)
df.head()
# Out:
#      ...  age=Middle-aged  capital-gain=Low  capital-loss=None  edu...  \
# 0  False             True              True               True   False
# 1  False             True              True               True   False
# 2  False             True              True               True   False
# 3  False             True              True               True   False
# 4  False             True              True               True   False
#
#    educati...  educatio...  education...  education=...  education=1...  ...  \
# 0       False         True         False          False           False  ...
# 1       False        False         False          False           False  ...
# 2       False        False         False          False           False  ...
# 3       False        False         False          False           False  ...
# 4       False        False         False          False           False  ...
#
#    relationship=Not-in-family  sex=Male  workclass=Federal-gov  \
# 0                        True      True                  False
# 1                        True      True                  False
# 2                        True      True                  False
# 3                        True      True                  False
# 4                        True      True                  False
#
#    workclass=Local-gov  workclass=Never-worked  workclass=Private  \
# 0                False                   False              False
# 1                False                   False               True
# 2                False                   False               True
# 3                False                   False               True
# 4                False                   False               True
#
#    workclass=Self-emp-inc  workclass=Self-emp-not-inc  workclass=State-gov  \
# 0                   False                        True                 True
# 1                   False                       False                 True
# 2                   False                       False                 True
# 3                   False                       False                 True
# 4                   False                       False                 True
#
#    workclass=Without-pay
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
#
# [5 rows x 180 columns]

# %% [markdown]
# ## 2. 연관규칙분석

# %% [markdown]
# ### 지지도가 0.4 이상인 연관규칙

# %%
frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)

frequent_itemsets
# Out:
#         support                                           itemsets
# 0      1.000000                                  (age=Middle-aged)
# 1      1.000000                                 (capital-gain=Low)
# 2      1.000000                                (capital-loss=None)
# 3      1.000000                              (education=Bachelors)
# 4      1.000000                         (hours-per-week=Full-time)
# ...         ...                                                ...
# 12282  0.694212  (sex=Male, relationship=Not-in-family, educati...
# 12283  0.505108  (sex=Male, relationship=Not-in-family, educati...
# 12284  0.694212  (sex=Male, relationship=Not-in-family, educati...
# 12285  0.505108  (sex=Male, relationship=Not-in-family, educati...
# 12286  0.694212  (sex=Male, relationship=Not-in-family, educati...
#
# [12287 rows x 2 columns]

# %% [markdown]
# ### 지지도가 0.4이상이면서 신뢰도가 0.7 이상인 item

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
rules
# Out:
#                                            antecedents  \
# 0                                    (age=Middle-aged)
# 1                                   (capital-gain=Low)
# 2                                  (capital-loss=None)
# 3                                    (age=Middle-aged)
# 4                                    (age=Middle-aged)
# ...                                                ...
# 1577935          (workclass=Private, capital-gain=Low)
# 1577936  (workclass=Private, hours-per-week=Full-time)
# 1577937       (workclass=Private, workclass=State-gov)
# 1577938         (workclass=Private, capital-loss=None)
# 1577939                            (workclass=Private)
#
#                                                consequents  \
# 0                                       (capital-gain=Low)
# 1                                        (age=Middle-aged)
# 2                                        (age=Middle-aged)
# 3                                      (capital-loss=None)
# 4                                    (education=Bachelors)
# ...                                                    ...
# 1577935  (sex=Male, relationship=Not-in-family, educati...
# 1577936  (sex=Male, relationship=Not-in-family, educati...
# 1577937  (sex=Male, relationship=Not-in-family, educati...
# 1577938  (sex=Male, relationship=Not-in-family, educati...
# 1577939  (sex=Male, relationship=Not-in-family, educati...
#
#          antecedent support  consequent support   support  confidence  lift  \
# 0                  1.000000                 1.0  1.000000         1.0   1.0
# 1                  1.000000                 1.0  1.000000         1.0   1.0
# 2                  1.000000                 1.0  1.000000         1.0   1.0
# 3                  1.000000                 1.0  1.000000         1.0   1.0
# 4                  1.000000                 1.0  1.000000         1.0   1.0
# ...                     ...                 ...       ...         ...   ...
# 1577935            0.694212                 1.0  0.694212         1.0   1.0
# 1577936            0.694212                 1.0  0.694212         1.0   1.0
# 1577937            0.694212                 1.0  0.694212         1.0   1.0
# 1577938            0.694212                 1.0  0.694212         1.0   1.0
# 1577939            0.694212                 1.0  0.694212         1.0   1.0
#
#          leverage  conviction
# 0             0.0         inf
# 1             0.0         inf
# 2             0.0         inf
# 3             0.0         inf
# 4             0.0         inf
# ...           ...         ...
# 1577935       0.0         inf
# 1577936       0.0         inf
# 1577937       0.0         inf
# 1577938       0.0         inf
# 1577939       0.0         inf
#
# [1577940 rows x 9 columns]

# %% [markdown]
# ### 지지도가 0.4이상이면서 신뢰도가 0.75 이상, 향상도 0.9이상인 item

# %%
rules[ (rules['confidence'] >= 0.75) &
       (rules['lift'] >= 0.9) ]
# Out:
#                                            antecedents  \
# 0                                    (age=Middle-aged)
# 1                                   (capital-gain=Low)
# 2                                  (capital-loss=None)
# 3                                    (age=Middle-aged)
# 4                                    (age=Middle-aged)
# ...                                                ...
# 1577935          (workclass=Private, capital-gain=Low)
# 1577936  (workclass=Private, hours-per-week=Full-time)
# 1577937       (workclass=Private, workclass=State-gov)
# 1577938         (workclass=Private, capital-loss=None)
# 1577939                            (workclass=Private)
#
#                                                consequents  \
# 0                                       (capital-gain=Low)
# 1                                        (age=Middle-aged)
# 2                                        (age=Middle-aged)
# 3                                      (capital-loss=None)
# 4                                    (education=Bachelors)
# ...                                                    ...
# 1577935  (sex=Male, relationship=Not-in-family, educati...
# 1577936  (sex=Male, relationship=Not-in-family, educati...
# 1577937  (sex=Male, relationship=Not-in-family, educati...
# 1577938  (sex=Male, relationship=Not-in-family, educati...
# 1577939  (sex=Male, relationship=Not-in-family, educati...
#
#          antecedent support  consequent support   support  confidence  lift  \
# 0                  1.000000                 1.0  1.000000         1.0   1.0
# 1                  1.000000                 1.0  1.000000         1.0   1.0
# 2                  1.000000                 1.0  1.000000         1.0   1.0
# 3                  1.000000                 1.0  1.000000         1.0   1.0
# 4                  1.000000                 1.0  1.000000         1.0   1.0
# ...                     ...                 ...       ...         ...   ...
# 1577935            0.694212                 1.0  0.694212         1.0   1.0
# 1577936            0.694212                 1.0  0.694212         1.0   1.0
# 1577937            0.694212                 1.0  0.694212         1.0   1.0
# 1577938            0.694212                 1.0  0.694212         1.0   1.0
# 1577939            0.694212                 1.0  0.694212         1.0   1.0
#
#          leverage  conviction
# 0             0.0         inf
# 1             0.0         inf
# 2             0.0         inf
# 3             0.0         inf
# 4             0.0         inf
# ...           ...         ...
# 1577935       0.0         inf
# 1577936       0.0         inf
# 1577937       0.0         inf
# 1577938       0.0         inf
# 1577939       0.0         inf
#
# [1577940 rows x 9 columns]
